# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv('sales_data.csv')

print("Dataset Overview:")
print(df.info())
print(df.head())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     9 non-null      object
#  1   Product  9 non-null      object
#  2   Sales    9 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 348.0+ bytes
# None
#          Date    Product  Sales
# 0  2024-01-01  Product A   1000
# 1  2024-01-02  Product B   1500
# 2  2024-01-03  Product C   1200
# 3  2024-02-01  Product A   1300
# 4  2024-02-02  Product B   1400

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df['Month'] = df['Date'].dt.to_period('M')

# %%
print("\nSales Summary:")
print(df.describe())
# Out:
# Sales Summary:
#                       Date        Sales
# count                    9     9.000000
# mean   2024-02-01 08:00:00  1472.222222
# min    2024-01-01 00:00:00  1000.000000
# 25%    2024-01-03 00:00:00  1300.000000
# 50%    2024-02-02 00:00:00  1500.000000
# 75%    2024-03-01 00:00:00  1700.000000
# max    2024-03-03 00:00:00  1800.000000
# std                    NaN   270.544718

# %%
import matplotlib.pyplot as plt

if 'Product' in df.columns and 'Sales' in df.columns:
    product_sales = df.groupby('Product')['Sales'].sum()
    print("\nTotal Sales per Product:")
    print(product_sales)

    # Ensure correct plotting
    plt.figure(figsize=(8, 5))
    product_sales.plot(kind='bar', title='Total Sales per Product', ylabel='Total Sales')
    plt.show()
# Out:
# Total Sales per Product:
# Product
# Product A    4000
# Product B    4700
# Product C    4550
# Name: Sales, dtype: int64

# %%
if 'Month' in df.columns and 'Sales' in df.columns:
    monthly_sales = df.groupby('Month')['Sales'].sum()
    print("\nMonthly Sales Trend:")
    print(monthly_sales)

    # Plot monthly sales trend
    plt.figure(figsize=(8, 5))
    monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend', ylabel='Total Sales')
    plt.show()
# Out:
# Monthly Sales Trend:
# Month
# 2024-01    3700
# 2024-02    4300
# 2024-03    5250
# Freq: M, Name: Sales, dtype: int64
